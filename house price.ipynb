# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
import warnings
# %matplotlib inline

# %%
train=pd.read_csv('C:/Users/basov/Desktop/house-prices-advanced-regression-techniques/train.csv')
test=pd.read_csv('C:/Users/basov/Desktop/house-prices-advanced-regression-techniques/test.csv')
train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 556    557          20       RL         69.0    14850   Pave   NaN      IR1
# 473    474          20       RL        110.0    14977   Pave   NaN      IR1
# 519    520          70       RL         53.0    10918   Pave   NaN      Reg
# 1380  1381          30       RL         45.0     8212   Pave  Grvl      Reg
# 994    995          20       RL         96.0    12456   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 556          Lvl    AllPub  ...        0    NaN   MnWw         NaN       0
# 473          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 519          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1380         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 994          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train=train.drop(['PoolQC','MiscFeature','Fence','Alley'],axis=1)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
num_cols=[x for x in train.describe()]
cat_cols=[x for x in train if x not in num_cols]

# %%
print(num_cols)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
#I checked all numerical columns and they are numerical, ok

# %%
print(cat_cols)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
train[train['Id'].isna() | train['Id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 77 columns]

# %%
train.corr().style.background_gradient(cmap="gray")
# Out:
# <style  type="text/css" >
# #T_87d26_row0_col0,#T_87d26_row1_col1,#T_87d26_row2_col2,#T_87d26_row3_col3,#T_87d26_row4_col4,#T_87d26_row5_col5,#T_87d26_row6_col6,#T_87d26_row7_col7,#T_87d26_row8_col8,#T_87d26_row9_col9,#T_87d26_row10_col10,#T_87d26_row11_col11,#T_87d26_row12_col12,#T_87d26_row13_col13,#T_87d26_row14_col14,#T_87d26_row15_col15,#T_87d26_row16_col16,#T_87d26_row17_col17,#T_87d26_row18_col18,#T_87d26_row19_col19,#T_87d26_row20_col20,#T_87d26_row21_col21,#T_87d26_row22_col22,#T_87d26_row23_col23,#T_87d26_row24_col24,#T_87d26_row25_col25,#T_87d26_row26_col26,#T_87d26_row27_col27,#T_87d26_row28_col28,#T_87d26_row29_col29,#T_87d26_row30_col30,#T_87d26_row31_col31,#T_87d26_row32_col32,#T_87d26_row33_col33,#T_87d26_row34_col34,#T_87d26_row35_col35,#T_87d26_row36_col36,#T_87d26_row37_col37{
#             background-color:  #ffffff;
#             color:  #000000;
# ...

# %%
fig, ax = plt.subplots(8, 5, figsize=(20, 35))
ax = ax.ravel()
for i, col in enumerate(num_cols):
    ax[i].plot(train[col])
    ax[i].set_title(col)

# %%
print(train["BsmtFinSF1"][train["BsmtFinSF1"]>5000])
print(train["TotalBsmtSF"][train["TotalBsmtSF"]>5000])
print(train["1stFlrSF"][train["1stFlrSF"]>4000])
#print(train["SalePrice"][train["SalePrice"]>700000])
#print(train["OpenPorchSF"][train["OpenPorchSF"]>500])
print(train["GrLivArea"][train["GrLivArea"]>5000])
# Out:
# 1298    5644
# Name: BsmtFinSF1, dtype: int64
# 1298    6110
# Name: TotalBsmtSF, dtype: int64
# 1298    4692
# Name: 1stFlrSF, dtype: int64
# 1298    5642
# Name: GrLivArea, dtype: int64

# %%
pd.set_option('display.max_columns', None)
data=pd.DataFrame(train[1295:1302])
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1295  1296          20       RL         70.0     8400   Pave      Reg
# 1296  1297          20       RL         80.0     8700   Pave      Reg
# 1297  1298         180       RM         35.0     3675   Pave      Reg
# 1298  1299          60       RL        313.0    63887   Pave      IR3
# 1299  1300          20       RL         75.0     7500   Pave      Reg
# 1300  1301          60       RL          NaN    10762   Pave      IR1
# 1301  1302          70       RL          NaN     7500   Pave      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1295         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1296         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1297         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1298         Bnk    AllPub    Corner       Gtl      Edwards      Feedr
# ...

# %% [markdown]
# В общем я не знаю как воспринимать строку 1298. С одной стороны в ней данные, которые выбиваются из общего вида данных, с другой стороны не так чтобы очень сильно.

# %%
useless = ['BsmtFinSF2','LowQualFinSF','BsmtHalfBath','YrSold','MoSold','MiscVal','3SsnPorch','ScreenPorch','PoolArea']
train = train.drop(useless, axis=1)

# %%
num_cols = [x for x in num_cols if x not in useless]

# %%
fig, ax = plt.subplots(10, 4, figsize=(20, 50))
ax = ax.ravel()
for i, col in enumerate(cat_cols):
    ax[i].pie(train[col].value_counts())
    ax[i].set_title(col)
    ax[i].legend(train[col].unique())

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...
